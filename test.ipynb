# %%
import pandas  as pd 
 
df = pd.read_csv(r"Dataset\retail_store_inventory.csv")
df.head()
# Out:
#          Date Store ID Product ID     Category Region  Inventory Level  \
# 0  2022-01-01     S001      P0001    Groceries  North              231
# 1  2022-01-01     S001      P0002         Toys  South              204
# 2  2022-01-01     S001      P0003         Toys   West              102
# 3  2022-01-01     S001      P0004         Toys  North              469
# 4  2022-01-01     S001      P0005  Electronics   East              166
#
#    Units Sold  Units Ordered  Demand Forecast  Price  Discount  \
# 0         127             55           135.47  33.50        20
# 1         150             66           144.04  63.01        20
# 2          65             51            74.02  27.99        10
# 3          61            164            62.18  32.72        10
# 4          14            135             9.26  73.64         0
#
#   Weather Condition  Holiday/Promotion  Competitor Pricing Seasonality
# 0             Rainy                  0               29.69      Autumn
# ...

# %%
df[df["Category"] == "Groceries"]
# Out:
#              Date Store ID Product ID   Category Region  Inventory Level  \
# 0      2022-01-01     S001      P0001  Groceries  North              231
# 5      2022-01-01     S001      P0006  Groceries  South              138
# 20     2022-01-01     S002      P0001  Groceries  South              343
# 26     2022-01-01     S002      P0007  Groceries   West              460
# 30     2022-01-01     S002      P0011  Groceries   West               67
# ...           ...      ...        ...        ...    ...              ...
# 73070  2024-01-01     S004      P0011  Groceries   East              155
# 73081  2024-01-01     S005      P0002  Groceries  North              253
# 73086  2024-01-01     S005      P0007  Groceries  South               59
# 73090  2024-01-01     S005      P0011  Groceries  North              156
# 73099  2024-01-01     S005      P0020  Groceries   East              117
#
#        Units Sold  Units Ordered  Demand Forecast  Price  Discount  \
# ...

# %%
df["Date"][df["Category"] == "Groceries"]
# Out:
# 0        2022-01-01
# 5        2022-01-01
# 20       2022-01-01
# 26       2022-01-01
# 30       2022-01-01
#             ...
# 73070    2024-01-01
# 73081    2024-01-01
# 73086    2024-01-01
# 73090    2024-01-01
# 73099    2024-01-01
# Name: Date, Length: 14611, dtype: object

# %%
df["Date"][df["Category"] == "Groceries"].value_counts()
# Out:
# Date
# 2023-05-05    35
# 2023-05-17    32
# 2022-09-26    31
# 2022-11-02    31
# 2022-01-14    30
#               ..
# 2023-07-24    11
# 2022-08-22    11
# 2023-08-16    10
# 2022-12-05    10
# 2023-02-12    10
# Name: count, Length: 731, dtype: int64
